# %%
import pandas as pd
df1 = pd.read_csv("C:/workspace/data/seoul_PM/seoul_PM.csv")
df2 = pd.read_csv("C:/workspace/data/기상정보/weather_preprocessed.csv")

# %%
df1
# Out:
#                          일시  구분  미세먼지(PM10)  초미세먼지(PM2.5)
# 0       2008-01-01 10:00:00  평균        44.0          22.0
# 1       2008-01-01 11:00:00  평균        38.0          23.0
# 2       2008-01-01 12:00:00  평균        41.0          23.0
# 3       2008-01-01 13:00:00  평균        40.0          29.0
# 4       2008-01-01 14:00:00  평균        45.0          25.0
# ...                     ...  ..         ...           ...
# 131488  2022-12-31 05:00:00  평균        43.0          32.0
# 131489  2022-12-31 06:00:00  평균        47.0          31.0
# 131490  2022-12-31 07:00:00  평균        49.0          32.0
# 131491  2022-12-31 08:00:00  평균        46.0          33.0
# 131492  2022-12-31 09:00:00  평균        46.0          34.0
#
# [131493 rows x 4 columns]

# %%
df2
# Out:
#                          일시  기온(°C)  강수량(mm)  풍속(m/s)  풍향(16방위)  습도(%)  \
# 0       2008-01-01 00:00:00    -7.0      0.0      3.5     270.0   52.0
# 1       2008-01-01 01:00:00    -7.3      0.0      4.9     290.0   52.0
# 2       2008-01-01 02:00:00    -7.5      0.0      4.1     270.0   52.0
# 3       2008-01-01 03:00:00    -7.8      0.0      3.9     270.0   52.0
# 4       2008-01-01 04:00:00    -7.9      0.0      4.0     290.0   53.0
# ...                     ...     ...      ...      ...       ...    ...
# 131491  2022-12-31 19:00:00    -0.2      0.0      1.8      20.0   73.0
# 131492  2022-12-31 20:00:00    -0.8      0.0      1.4      20.0   75.0
# 131493  2022-12-31 21:00:00    -1.0      0.0      0.9     340.0   77.0
# 131494  2022-12-31 22:00:00    -0.8      0.0      0.5     290.0   78.0
# 131495  2022-12-31 23:00:00    -0.2      0.0      1.3     230.0   77.0
#
#         증기압(hPa)  이슬점온도(°C)  현지기압(hPa)  해면기압(hPa)  ...  전운량(10분위)  \
# ...

# %%
df = pd.merge(df1, df2, on = '일시', how = 'inner')

# %%
df
# Out:
#                          일시  구분  미세먼지(PM10)  초미세먼지(PM2.5)  기온(°C)  강수량(mm)  \
# 0       2008-01-01 10:00:00  평균        44.0          22.0    -7.6      0.0
# 1       2008-01-01 11:00:00  평균        38.0          23.0    -6.9      0.0
# 2       2008-01-01 12:00:00  평균        41.0          23.0    -5.8      0.0
# 3       2008-01-01 13:00:00  평균        40.0          29.0    -5.0      0.0
# 4       2008-01-01 14:00:00  평균        45.0          25.0    -4.4      0.0
# ...                     ...  ..         ...           ...     ...      ...
# 131488  2022-12-31 05:00:00  평균        43.0          32.0    -3.4      0.0
# 131489  2022-12-31 06:00:00  평균        47.0          31.0    -3.5      0.0
# 131490  2022-12-31 07:00:00  평균        49.0          32.0    -3.9      0.0
# 131491  2022-12-31 08:00:00  평균        46.0          33.0    -4.0      0.0
# 131492  2022-12-31 09:00:00  평균        46.0          34.0    -3.5      0.0
#
# ...
